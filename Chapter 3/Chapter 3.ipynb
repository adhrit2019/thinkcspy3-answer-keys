# %% [markdown]
# ## CHAPTER THREE
# # HELLO, LITTLE TURTLES!

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Question 1

# %%
# %run Chapter-3-Question-1.py
# Out:
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# ...

# %% [markdown]
# #### Question 2

# %% [markdown]
# Three attributes of a cellphone could be:
# * It's height
# * It's memory
# * It's operating system
#
# Three methods of a cellphone could be:
# * for answering calls
# * for entertainment
# * for media

# %% [markdown]
# #### Question 3

# %%
# %run Chapter-3-Question-3.py
# Out:
# One of the months of the year is January
# One of the months of the year is February
# One of the months of the year is March
# One of the months of the year is April
# One of the months of the year is May
# One of the months of the year is June
# One of the months of the year is July
# One of the months of the year is August
# One of the months of the year is September
# One of the months of the year is October
# One of the months of the year is November
# One of the months of the year is December

# %% [markdown]
# #### Question 4

# %% [markdown]
# When we execute the statement `tess.left(3645)`, it makes ten 360&deg; rotations and ends with 45&deg; rotation.

# %% [markdown]
# #### Question 5

# %%
xs = [12, 10, 32, 3, 66, 17, 42, 99, 20]

# %%
# (a)
for x in xs:
    print(x)
# Out:
# 12
# 10
# 32
# 3
# 66
# 17
# 42
# 99
# 20

# %%
# (b)
for x in xs:
    print(str(x) + ": " + str(x ** 2))
# Out:
# 12: 144
# 10: 100
# 32: 1024
# 3: 9
# 66: 4356
# 17: 289
# 42: 1764
# 99: 9801
# 20: 400

# %%
# (c)
total = 0

for x in xs:
    total = total + x
    
print(total)
# Out:
# 301

# %%
# (d)
prod = 1

for x in xs:
    prod = prod * x
    
print(prod)
# Out:
# 1074879590400

# %% [markdown]
# #### Question 6

# %%
# equilateral triangle
# %run Chapter-3-Question-6-triangle.py

# %%
# square
# %run Chapter-3-Question-6-square.py

# %%
# hexagon
# %run Chapter-3-Question-6-hexagon.py

# %%
# octagon
# %run Chapter-3-Question-6-octagon.py

# %% [markdown]
# #### Question 7

# %%
# %run Chapter-3-Question-7.py

# %% [markdown]
# #### Question 8

# %%
# %run Chapter-3-Question-8.py
# Out:
# The pirate's last heading is in -86 degrees

# %% [markdown]
# #### Question 9

# %% [markdown]
# If I were to draw a polygon with a given number of sides, say $s$. The angle which I would need $(360 \div s)$&deg;. Therefore, with the given number of sides as 18, the angle I would need is 20&deg;.

# %% [markdown]
# #### Question 10

# %%
# %run Chapter-3-Question-10.py

# %% [markdown]
# #### Question 11

# %%
# %run Chapter-3-Question-11.py

# %% [markdown]
# #### Question 12

# %%
# %run Chapter-3-Question-12.py

# %% [markdown]
# #### Question 13

# %%
import turtle

# %%
tess = turtle.Turtle()
type(tess)
# Out:
# turtle.Turtle

# %% [markdown]
# #### Question 14

# %% [markdown]
# The collective noun for turtles is "bale".

# %% [markdown]
# #### Question 15

# %% [markdown]
# The collective noun for pythons is "bed". Python is **not** a viper. A few varieties of pythons are venomous.
